# %%
import pandas as pd

# %%
pgviews = pd.read_csv('/Users/janet/Desktop/2nd Year - UCLA/spring24/Datafest 2024/Data/Random Sample of Data Files/responses.csv')

pgviews.head()
# Out:
# /var/folders/2f/8zhq5vms7nq60_g8p7n60d640000gn/T/ipykernel_77118/217085209.py:1: DtypeWarning: Columns (34,35,36,37,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   pgviews = pd.read_csv('/Users/janet/Desktop/2nd Year - UCLA/spring24/Datafest 2024/Data/Random Sample of Data Files/responses.csv')
#                                                 book    release  \
# 0  College / Advanced Statistics and Data Science...  v5.0-exp2
# 1  College / Advanced Statistics and Data Science...  v5.0-exp2
# 2  College / Advanced Statistics and Data Science...  v5.0-exp2
# 3  College / Advanced Statistics and Data Science...  v5.0-exp2
# 4  College / Advanced Statistics and Data Science...  v5.0-exp2
#
#                                              chapter  \
# 0  Chapter 1 - Welcome to Statistics: A Modeling ...
# 1  Chapter 1 - Welcome to Statistics: A Modeling ...
# 2  Chapter 1 - Welcome to Statistics: A Modeling ...
# ...

# %%
cp_eoc = pd.read_csv('/Users/janet/Desktop/2nd Year - UCLA/spring24/Datafest 2024/Data/Random Sample of Data Files/checkpoints_eoc.csv')

cp_eoc.head()
# Out:
#                              student_id                              class_id  \
# 0  001824fb-a2fd-431d-aef6-7a1250d97a62  074123e7-cd90-4500-86fe-286aaa733bf5
# 1  001824fb-a2fd-431d-aef6-7a1250d97a62  074123e7-cd90-4500-86fe-286aaa733bf5
# 2  001824fb-a2fd-431d-aef6-7a1250d97a62  074123e7-cd90-4500-86fe-286aaa733bf5
# 3  001824fb-a2fd-431d-aef6-7a1250d97a62  074123e7-cd90-4500-86fe-286aaa733bf5
# 4  001824fb-a2fd-431d-aef6-7a1250d97a62  074123e7-cd90-4500-86fe-286aaa733bf5
#
#    chapter_number                                         book       EOC  \
# 0               1  College / Statistics and Data Science (ABC)  0.921053
# 1               2  College / Statistics and Data Science (ABC)  0.839080
# 2               3  College / Statistics and Data Science (ABC)  0.769231
# 3               4  College / Statistics and Data Science (ABC)  0.743590
# 4               5  College / Statistics and Data Science (ABC)  0.777778
#
#    n_possible  n_correct  n_attempt
# ...

# %%
rsps = pd.read_csv('/Users/janet/Desktop/2nd Year - UCLA/spring24/Datafest 2024/Data/Random Sample of Data Files/responses.csv')

rsps.head()
# Out:
# /var/folders/2f/8zhq5vms7nq60_g8p7n60d640000gn/T/ipykernel_77118/1363586250.py:1: DtypeWarning: Columns (34,35,36,37,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   rsps = pd.read_csv('/Users/janet/Desktop/2nd Year - UCLA/spring24/Datafest 2024/Data/Random Sample of Data Files/responses.csv')
#                                                 book    release  \
# 0  College / Advanced Statistics and Data Science...  v5.0-exp2
# 1  College / Advanced Statistics and Data Science...  v5.0-exp2
# 2  College / Advanced Statistics and Data Science...  v5.0-exp2
# 3  College / Advanced Statistics and Data Science...  v5.0-exp2
# 4  College / Advanced Statistics and Data Science...  v5.0-exp2
#
#                                              chapter  \
# 0  Chapter 1 - Welcome to Statistics: A Modeling ...
# 1  Chapter 1 - Welcome to Statistics: A Modeling ...
# 2  Chapter 1 - Welcome to Statistics: A Modeling ...
# ...

# %%
df = pd.merge(pgviews, cp_eoc, on='student_id', how='inner')
df = pd.merge(df, rsps, on='student_id', how='inner')

df.head()
